# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
file = pd.read_csv("/content/historical_automobile_sales.csv")
file
# Out:
#            Date  Year Month  Recession  Consumer_Confidence  \
# 0     1/31/1980  1980   Jan          1               108.24
# 1     2/29/1980  1980   Feb          1                98.75
# 2     3/31/1980  1980   Mar          1               107.48
# 3     4/30/1980  1980   Apr          1               115.01
# 4     5/31/1980  1980   May          1                98.72
# ..          ...   ...   ...        ...                  ...
# 523   8/31/2023  2023   Aug          0               103.36
# 524   9/30/2023  2023   Sep          0               101.55
# 525  10/31/2023  2023   Oct          0               124.66
# 526  11/30/2023  2023   Nov          0                97.09
# 527  12/31/2023  2023   Dec          0                95.92
#
#      Seasonality_Weight      Price  Advertising_Expenditure  Competition  \
# 0                  0.50  27483.571                     1558            7
# 1                  0.75  24308.678                     3048            4
# ...

# %%
# Q 1: Develop a Line chart using the functionality of pandas to show how automobile sales fluctuate from year to year.

saless = file.groupby('Year')['Automobile_Sales'].sum().reset_index()
plt.figure(figsize=(5,5))
plt.plot(saless['Year'], saless['Automobile_Sales'], marker='o')
plt.title('Total Automobile Sales per Year')
plt.xlabel('Year')
plt.ylabel('Sales (Units)')
plt.grid(True)
plt.show()

# %%
# Q2: Plot different lines for categories of vehicle type and analyze the trend to answer the question Is there a noticeable difference in sales trends between different vehicle types during recession periods?

sales_ = file.groupby(['Year','Vehicle_Type'])['Automobile_Sales'].sum().reset_index()
plt.figure(figsize=(6,6))
for vtype, sub in sales_.groupby('Vehicle_Type'):
    plt.plot(sub['Year'], sub['Automobile_Sales'], label=vtype)
plt.title('Yearly Automobile Sales by Vehicle Type')
plt.xlabel('Year')
plt.ylabel('Sales (Units)')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Q3: Use the functionality of Seaborn Library to create a visualization to compare the sales trend per vehicle type for a recession period with a non- recession period.

plt.figure(figsize=(6,6))
sns.lineplot(data=file, x='Year', y='Automobile_Sales', hue='Recession')
plt.title('Sales Trend per Vehicle Type: Recession vs Non-Recession')
plt.xlabel('Year')
plt.ylabel('Sales (Units)')
plt.show()

# %%
# Q4: Now you want to compare the sales of different vehicle types during a recession and a non-recession period

avg_sales = file.groupby(['Recession','Vehicle_Type'])['Automobile_Sales'].mean().reset_index()
plt.figure(figsize=(6,6))
sns.barplot(data=avg_sales, x='Vehicle_Type', y='Automobile_Sales', hue='Recession')
plt.title('Average Automobile Sales by Vehicle Type: Recession (1) vs Non-Recession (0)')
plt.ylabel('Average Sales (Units)')
plt.xticks(rotation=45)
plt.show()
